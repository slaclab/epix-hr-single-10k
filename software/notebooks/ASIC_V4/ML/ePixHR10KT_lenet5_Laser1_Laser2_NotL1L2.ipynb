# %%
# Setup the library
import pyrogue as pr
import os, sys
import matplotlib.pyplot as plt
import time
import numpy as np
import math

top_level=f'{os.getcwd()}/../../../'
pr.addLibraryPath( f'{top_level}/scripts' )
import setupLibPaths
import epix_hr_single_10k
import ePixViewer.Cameras as cameras

# %run ./supportFunctionsForML.ipynb

# %% [markdown]
# # Read and visualize data

# %%
dataset_type = "training"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_dark_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (2000, 145, 384)

# %%
dataset_type = "validation"

filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_dark_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (2000, 145, 384)

# %%
dataset_type = "test"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_dark_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (2000, 145, 384)

# %%
dataset_type = "training"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_diff_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (18000, 145, 384)

# %%
dataset_type = "validation"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_diff_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (18000, 145, 384)

# %%
dataset_type = "test"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_diff_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (18000, 145, 384)

# %%
dataset_type = "training"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_round_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (2000, 145, 384)

# %%
dataset_type = "validation"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_round_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (2000, 145, 384)

# %%
dataset_type = "test"
filename = (f'/u2/ddoering/MLDatasets/ePixHR10k/BareASIC/LaserPointer/ePixHR10kTLCLSIITiming_ASICV4_ASIC2_round_%s.npy' % (dataset_type))
test_dataset = np.load(filename)
print(test_dataset.shape)

show_random_images(test_dataset, dataset_type)
# Out:
# (18000, 145, 384)

# %% [markdown]
# # Creat Model

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten, Conv2D, MaxPooling2D # new!
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import keras
#       2 from keras.datasets import mnist
#       3 from keras.models import Sequential
#
# File /afs/slac.stanford.edu/g/reseng/vol31/anaconda/anaconda3/envs/rogue_v5.18.4/lib/python3.9/site-packages/keras/__init__.py:1
# ----> 1 from keras import activations
#       2 from keras import applications
#       3 from keras import backend
#
# File /afs/slac.stanford.edu/g/reseng/vol31/anaconda/anaconda3/envs/rogue_v5.18.4/lib/python3.9/site-packages/keras/activations/__init__.py:3
#       1 import types
# ----> 3 from keras.activations.activations import elu
#       4 from keras.activations.activations import exponential
#       5 from keras.activations.activations import gelu
#
# File /afs/slac.stanford.edu/g/reseng/vol31/anaconda/anaconda3/envs/rogue_v5.18.4/lib/python3.9/site-packages/keras/activations/activations.py:1
# ----> 1 from keras import backend
#       2 from keras import ops
#       3 from keras.api_export import keras_export
#
# File /afs/slac.stanford.edu/g/reseng/vol31/anaconda/anaconda3/envs/rogue_v5.18.4/lib/python3.9/site-packages/keras/backend/__init__.py:33
#      31 # Import backend functions.
#      32 if backend() == "tensorflow":
# ---> 33     from keras.backend.tensorflow import *  # noqa: F403
#      34 elif backend() == "jax":
#      35     from keras.backend.jax import *  # noqa: F403
#
# File /afs/slac.stanford.edu/g/reseng/vol31/anaconda/anaconda3/envs/rogue_v5.18.4/lib/python3.9/site-packages/keras/backend/tensorflow/__init__.py:1
# ----> 1 from keras.backend.tensorflow import core
#       2 from keras.backend.tensorflow import distribution_lib
#       3 from keras.backend.tensorflow import image
#
# File /afs/slac.stanford.edu/g/reseng/vol31/anaconda/anaconda3/envs/rogue_v5.18.4/lib/python3.9/site-packages/keras/backend/tensorflow/core.py:4
#       1 import types
#       3 import numpy as np
# ----> 4 import tensorflow as tf
#       5 from tensorflow.compiler.tf2xla.python.xla import dynamic_update_slice
#       7 from keras.backend.common import KerasVariable
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# # Train Model

# %% [markdown]
# # Inference Examples
